# %%
import os
import sys

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns


ROOT_DIR = os.path.dirname(
os.path.dirname(os.path.abspath('')))


sys.path.append(os.path.join(ROOT_DIR, "code"))


# Define global variables
DATA_DIR = os.path.join(ROOT_DIR, "data/")

PLOT_DIR = os.path.join(ROOT_DIR, "plots/eda/")

DATA_PATH = os.path.join(DATA_DIR, "data.csv")

# %%
data = pd.read_csv(DATA_PATH, index_col=0, na_filter=False)

# %%
data.describe()
# Out:
#              ecutrho      k_density        ecutwfc   n_iterations  \
# count  540569.000000  540569.000000  540569.000000  540569.000000
# mean      244.254813       5.912648      56.923695      17.064153
# std        89.487745       2.819989      23.861532      11.149028
# min       100.000000       2.000000      20.000000       6.000000
# 25%       180.000000       4.000000      35.000000      10.000000
# 50%       260.000000       6.000000      55.000000      12.000000
# 75%       340.000000       8.000000      75.000000      20.000000
# max       380.000000      10.000000     100.000000     100.000000
#
#                time      accuracy          fermi   total_energy        delta_E
# count  5.405690e+05  5.405690e+05  540569.000000  540569.000000  540569.000000
# mean   9.702177e+04  3.411534e-10      12.639449    -236.071954       0.051309
# std    1.509399e+05  2.838775e-10       5.491578     168.582942       0.224061
# min    3.900000e+01  1.600000e-15      -4.982300    -931.004220      -0.447845
# 25%    1.004000e+04  9.200000e-11       8.846400    -321.470364       0.000015
# 50%    4.311000e+04  2.600000e-10      12.605100    -192.969718       0.000847
# 75%    1.260710e+05  5.500000e-10      17.001200    -104.191465       0.010376
# max    3.009146e+06  1.000000e-09      25.644000      -7.732576       3.775258

# %%
blue = "#0063be"
yellow = "#fed900"
green = "#007836"
orange = "#ff6f20"
purple = "#580f8b"

# %%
PLOT_PATH = os.path.join(PLOT_DIR, "sim_time.png")
os.makedirs(PLOT_DIR, exist_ok=True)
fs = 12
fig, ax = plt.subplots(1, 2, figsize=(6,3))
sns.kdeplot(data['time'], ax=ax[0], c=blue)
sns.kdeplot(np.log(data['time']), ax=ax[1], c=blue)

ax[0].set_xlabel("$Sim. time$", fontsize=fs)
ax[1].set_xlabel("$\\log(Sim. time$)", fontsize=fs)
plt.savefig(PLOT_PATH)
plt.show()
