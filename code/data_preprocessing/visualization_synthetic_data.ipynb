# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib notebook

# %%
DATA_PATH1 = os.path.join(os.path.dirname(os.path.dirname(os.getcwd())), "data/toy_data.csv")
DATA_PATH2 = os.path.join(os.path.dirname(os.path.dirname(os.getcwd())), "data/toy_data2.csv")

# %%
df1 = pd.read_csv(DATA_PATH1)
df2 = pd.read_csv(DATA_PATH2)

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'ecutrho', 'k_density', 'ecutwfc', 'converged',
#        'accuracy', 'total_energy', 'Ag', 'Al', 'Ar', 'As', 'Au', 'B', 'Ba',
#        'Be', 'Bi', 'Br', 'C', 'Ca', 'Cd', 'Ce', 'Cl', 'Co', 'Cr', 'Cs', 'Cu',
#        'Dy', 'Er', 'Eu', 'F', 'Fe', 'Ga', 'Gd', 'Ge', 'H', 'He', 'Hf', 'Hg',
#        'Ho', 'I', 'In', 'Ir', 'K', 'Kr', 'La', 'Li', 'Lu', 'Mg', 'Mn', 'Mo',
#        'N', 'Na', 'Nb', 'Nd', 'Ne', 'Ni', 'O', 'Os', 'P', 'Pb', 'Pd', 'Pm',
#        'Po', 'Pr', 'Pt', 'Rb', 'Re', 'Rh', 'Rn', 'Ru', 'S', 'Sb', 'Sc', 'Se',
#        'Si', 'Sm', 'Sn', 'Sr', 'Ta', 'Tb', 'Tc', 'Te', 'Ti', 'Tl', 'Tm', 'V',
#        'W', 'Xe', 'Y', 'Yb', 'Zn', 'Zr'],
#       dtype='object')

# %%
fig1 = plt.figure()
ax1 = fig1.add_subplot(111, projection='3d')
ax1.scatter(df1['ecutwfc'], df1['k_density'], df1['total_energy'])
ax1.scatter(df2['ecutwfc'], df2['k_density'], df2['total_energy'])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig2 = plt.figure()
ax2 = fig2.add_subplot(111, projection='3d')
ax2.scatter(df2['ecutwfc'], df2['k_density'], df2['total_energy'])
# Out:
# <img src="data:image/png;base64,..." width="640">
