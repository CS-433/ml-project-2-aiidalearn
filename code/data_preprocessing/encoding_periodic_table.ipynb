# %%
import json
import os
import requests

# %% [markdown]
# # Loading all element keys from `www.materialscloud.org`

# %%
# LOADING ALL ELEMENT KEYS
url_table = requests.get("https://archive.materialscloud.org/record/file?record_id=862&filename=SSSP_1.1.2_PBE_efficiency.json&file_id=a5642f40-74af-4073-8dfd-706d2c7fccc2")
text_table = url_table.text
sssp_table = json.loads(text_table)
periodic_table_keys = list(sssp_table.keys())

# %% [markdown]
# # Encoding the column in the periodic table of elements

# %%
c1 = ['H', 'Li', 'Na', 'K', 'Rb', 'Cs']
c2 = ['Be', 'Mg', 'Ca', 'Sr', 'Ba']
c3 = ['Sc', 'Y', ' ']
c4 = ['Ti', 'Zr', 'Hf']
c5 = ['V', 'Nb', 'Ta']
c6 = ['Cr', 'Mo', 'W']
c7 = ['Mn', 'Tc', 'Re']
c8 = ['Fe', 'Ru', 'Os']
c9 = ['Co', 'Rh', 'Ir']
c10 = ['Ni', 'Pd', 'Pt']
c11 = ['Cu', 'Ag', 'Au']
c12 = ['Zn', 'Cd', 'Hg']
c13 = ['B', 'Al', 'Ga', 'In', 'Tl']
c14 = ['C', 'Si', 'Ge', 'Sn', 'Pb']
c15 = ['N', 'P', 'As', 'Sb', 'Bi']
c16 = ['O', 'S', 'Se', 'Te', 'Po']
c17 = ['F', 'Cl', 'Br', 'I', ' ']
c18 = ['He', 'Ne', 'Ar', 'Kr', 'Xe', 'Rn']
cols = [c1, c2, c3, c4, c5, c6, c7, c8, c9, c10, c11, c12, c13, c14, c15, c16, c17, c18]
lanthanides = ['La', 'Ce', 'Pr', 'Nd', 'Pm', 'Sm', 'Eu', 'Gd', 'Tb', 'Dy', 'Ho', 'Er', 'Tm', 'Yb', 'Lu']

# %% [markdown]
# # Encoding the relative atomic masses

# %%
atomic_masses = {}
for element in periodic_table_keys:
    atomic_masses[element] = 0.0

# %%
atomic_masses['H'] = 1.0079
atomic_masses['He'] = 4.0026
atomic_masses['Li'] = 6.941
atomic_masses['Be'] = 9.0122
atomic_masses['B'] = 10.811
atomic_masses['C'] = 12.0107
atomic_masses['N'] = 14.0067
atomic_masses['O'] = 15.9994
atomic_masses['F'] = 18.9984
atomic_masses['Ne'] = 20.1797
atomic_masses['Na'] = 22.9897
atomic_masses['Mg'] = 24.305
atomic_masses['Al'] = 26.9815
atomic_masses['Si'] = 28.0855
atomic_masses['P'] = 30.9738
atomic_masses['S'] = 32.065
atomic_masses['Cl'] = 35.453
atomic_masses['Ar'] = 39.948
atomic_masses['K'] = 39.0983
atomic_masses['Ca'] = 40.078
atomic_masses['Sc'] = 44.9559
atomic_masses['Ti'] = 47.867
atomic_masses['V'] = 50.9415
atomic_masses['Cr'] = 51.9961
atomic_masses['Mn'] = 54.938
atomic_masses['Fe'] = 55.845
atomic_masses['Ni'] = 58.6934
atomic_masses['Co'] = 58.9332
atomic_masses['Cu'] = 63.546
atomic_masses['Zn'] = 65.39
atomic_masses['Ga'] = 69.723
atomic_masses['Ge'] = 72.64
atomic_masses['As'] = 74.9216
atomic_masses['Se'] = 78.96
atomic_masses['Br'] = 79.904
atomic_masses['Kr'] = 83.8
atomic_masses['Rb'] = 85.4678
atomic_masses['Sr'] = 87.62
atomic_masses['Y'] = 88.9059
atomic_masses['Zr'] = 91.224
atomic_masses['Nb'] = 92.9064
atomic_masses['Mo'] = 95.94
atomic_masses['Tc'] = 98
atomic_masses['Ru'] = 101.07
atomic_masses['Rh'] = 102.9055
atomic_masses['Pd'] = 106.42
atomic_masses['Ag'] = 107.8682
atomic_masses['Cd'] = 112.411
atomic_masses['In'] = 114.818
atomic_masses['Sn'] = 118.71
atomic_masses['Sb'] = 121.76
atomic_masses['I'] = 126.904 
atomic_masses['Te'] = 127.6
atomic_masses['Xe'] = 131.293
atomic_masses['Cs'] = 132.9055
atomic_masses['Ba'] = 137.327
atomic_masses['La'] = 138.9055
atomic_masses['Ce'] = 140.116
atomic_masses['Pr'] = 140.9077
atomic_masses['Nd'] = 144.24
atomic_masses['Pm'] = 145
atomic_masses['Sm'] = 150.36
atomic_masses['Eu'] = 151.964
atomic_masses['Gd'] = 157.25
atomic_masses['Tb'] = 158.9253
atomic_masses['Dy'] = 162.5
atomic_masses['Ho'] = 164.9303
atomic_masses['Er'] = 167.259
atomic_masses['Tm'] = 168.9342
atomic_masses['Yb'] = 172.04
atomic_masses['Lu'] = 174.967
atomic_masses['Hf'] = 178.49
atomic_masses['Ta'] = 180.9479
atomic_masses['W'] = 183.84
atomic_masses['Re'] = 186.207
atomic_masses['Os'] = 190.23
atomic_masses['Ir'] = 192.217
atomic_masses['Pt'] = 195.078
atomic_masses['Au'] = 196.9665
atomic_masses['Hg'] = 200.59
atomic_masses['Tl'] = 204.3833
atomic_masses['Pb'] = 207.2
atomic_masses['Bi'] = 208.9804
atomic_masses['Po'] = 209
atomic_masses['At'] = 210
atomic_masses['Rn'] = 222
atomic_masses['Fr'] = 223
atomic_masses['Ra'] = 226
atomic_masses['Ac'] = 227
atomic_masses['Pa'] = 231.0359
atomic_masses['Th'] = 232.0381
atomic_masses['Np'] = 237
atomic_masses['U'] = 238.0289
atomic_masses['Am'] = 243
atomic_masses['Pu'] = 244
atomic_masses['Cm'] = 247
atomic_masses['Bk'] = 247
atomic_masses['Cf'] = 251
atomic_masses['Es'] = 252
atomic_masses['Fm'] = 257
atomic_masses['Md'] = 258
atomic_masses['No'] = 259
atomic_masses['Rf'] = 261
atomic_masses['Lr'] = 262
atomic_masses['Db'] = 262
atomic_masses['Bh'] = 264
atomic_masses['Sg'] = 266
atomic_masses['Mt'] = 268
atomic_masses['Rg'] = 272
atomic_masses['Hs'] = 277

# %% [markdown]
# ## Valence Bands

# %%
valence_bands = {}
for element in periodic_table_keys:
    valence_bands[element] = " "

# %%
valence_bands['H'] = "1s^1"
valence_bands['He'] = "1s^2"
valence_bands['Li'] = "2s^1"
valence_bands['Be'] = "2s^2"
valence_bands['B'] = "2s^2-2p^1"
valence_bands['C'] = "2s^2-2p^2"
valence_bands['N'] = "2s^2-2p^3"
valence_bands['O'] = "2s^2-2p^4"
valence_bands['F'] = "2s^2-2p^5"
valence_bands['Ne'] = "2s^2-2p^6"
valence_bands['Na'] = "3s^1"
valence_bands['Mg'] = "3s^2"
valence_bands['Al'] = "3s^2-3p^1"
valence_bands['Si'] = "3s^2-3p^2"
valence_bands['P'] = "3s^2-3p^3"
valence_bands['S'] = "3s^2-3p^4"
valence_bands['Cl'] = "3s^2-3p^5"
valence_bands['Ar'] = "3s^2-3p^6"
valence_bands['K'] = "4s^1"
valence_bands['Ca'] = "4s^2"
valence_bands['Sc'] = "3d^1-4s^2"
valence_bands['Ti'] = "3d^2-4s^2"
valence_bands['V'] =  "3d^3-4s^2"
valence_bands['Cr'] = "3d^4-4s^2"
valence_bands['Mn'] = "3d^5-4s^2"
valence_bands['Fe'] = "3d^6-4s^2"
valence_bands['Ni'] = "3d^7-4s^2"
valence_bands['Co'] = "3d^8-4s^2"
valence_bands['Cu'] = "3d^10-4s^1"
valence_bands['Zn'] = "3d^10-4s^2"
valence_bands['Ga'] = "3d^10-4s^2-4p^1"
valence_bands['Ge'] = "3d^10-4s^2-4p^2"
valence_bands['As'] = "3d^10-4s^2-4p^3"
valence_bands['Se'] = "3d^10-4s^2-4p^4"
valence_bands['Br'] = "3d^10-4s^2-4p^5"
valence_bands['Kr'] = "3d^10-4s^2-4p^6"
valence_bands['Rb'] = "5s^1"
valence_bands['Sr'] = "5s^2"
valence_bands['Y'] =  "4d^1-5s^2"
valence_bands['Zr'] = "4d^2-5s^2"
valence_bands['Nb'] = "4d^4-5s^1"
valence_bands['Mo'] = "4d^5-5s^1"
valence_bands['Tc'] = "4d^5-5s^2"
valence_bands['Ru'] = "4d^7-5s^1"
valence_bands['Rh'] = "4d^8-5s^1"
valence_bands['Pd'] = "4d^10"
valence_bands['Ag'] = "4d^10-5s^1"
valence_bands['Cd'] = "4d^10-5s^2"
valence_bands['In'] = "4d^10-5s^2-5p^1"
valence_bands['Sn'] = "4d^10-5s^2-5p^2"
valence_bands['Sb'] = "4d^10-5s^2-5p^3"
valence_bands['Te'] =  "4d^10-5s^2-5p^4"
valence_bands['I'] = "4d^10-5s^2-5p^5"
valence_bands['Xe'] = "4d^10-5s^2-5p^6"
valence_bands['Cs'] = "6s^1"
valence_bands['Ba'] = "6s^2"
valence_bands['La'] = "5d^1-6s^1"
valence_bands['Ce'] = "4f^1-5d^1-6s^1"
valence_bands['Pr'] = "4f^3-6s^2"
valence_bands['Nd'] = "4f^4-6s^2"
valence_bands['Pm'] = "4f^5-6s^2"
valence_bands['Sm'] = "4f^6-6s^2"
valence_bands['Eu'] = "4f^7-6s^2"
valence_bands['Gd'] = "4f^7-5d^1-6s^2"
valence_bands['Tb'] = "4f^9-6s^2"
valence_bands['Dy'] = "4f^10-6s^2"
valence_bands['Ho'] = "4f^11-6s^2"
valence_bands['Er'] = "4f^12-6s^2"
valence_bands['Tm'] = "4f^13-6s^2"
valence_bands['Yb'] = "4f^14-6s^2"
valence_bands['Lu'] = "4f^14-5d^1-6s^2"
valence_bands['Hf'] = "4f^14-5d^2-6s^2"
valence_bands['Ta'] = "4f^14-5d^3-6s^2"
valence_bands['W'] =  "4f^14-5d^4-6s^2"
valence_bands['Re'] = "4f^14-5d^5-6s^2"
valence_bands['Os'] = "4f^14-5d^6-6s^2"
valence_bands['Ir'] = "4f^14-5d^7-6s^2"
valence_bands['Pt'] = "4f^14-5d^9-6s^1"
valence_bands['Au'] = "4f^14-5d^10-6s^1"
valence_bands['Hg'] = "4f^14-5d^10-6s^2"
valence_bands['Tl'] = "4f^14-5d^10-6s^2-6p^1"
valence_bands['Pb'] = "4f^14-5d^10-6s^2-6p^2"
valence_bands['Bi'] = "4f^14-5d^10-6s^2-6p^3"
valence_bands['Po'] = "4f^14-5d^10-6s^2-6p^4"
valence_bands['At'] = "4f^14-5d^10-6s^2-6p^5"
valence_bands['Rn'] = "4f^14-5d^10-6s^2-6p^6"
valence_bands['Fr'] = "7s^1"
valence_bands['Ra'] = "7s^2"
valence_bands['Ac'] = "6d^1-7s^2"
valence_bands['Th'] = "6d^2-7s^2"
valence_bands['Pa'] = "5f^2-6d^1-7s^2"
valence_bands['Np'] = "5f^3-6d^1-7s^2"
valence_bands['U'] =  "5f^4-6d^1-7s^2"
valence_bands['Am'] = "5f^6-7s^2"
valence_bands['Pu'] = "5f^7-7s^2"
valence_bands['Cm'] = "5f^7-6d^1-7s^2"
valence_bands['Bk'] = "5f^9-7s^2"
valence_bands['Cf'] = "5f^10-7s^2"
valence_bands['Es'] = "5f^11-7s^2"
valence_bands['Fm'] = "5f^12-7s^2"
valence_bands['Md'] = "5f^13-7s^2"
valence_bands['No'] = "5f^14-7s^2"
valence_bands['Rf'] = "5f^14-6d^2-7s^2"
valence_bands['Lr'] = "5f^14-7s^2-7p^1"
valence_bands['Db'] = "5f^14-6d^3-7s^2"
valence_bands['Bh'] = "5f^14-6d^5-7s^2"
valence_bands['Sg'] = "5f^14-6d^4-7s^2"
valence_bands['Mt'] = "5f^14-6d^7-7s^2"
valence_bands['Rg'] = "5f^14-6d^9-7s^2"
valence_bands['Hs'] = "5f^14-6d^6-7s^2"

# %% [markdown]
# # Combining the information

# %%
periodic_table_info = {}
for element in periodic_table_keys:
    element_info = {'mass' : atomic_masses[element], 'valence_band' : valence_bands[element]}
    for col in cols:
        if element in col:
            i = col.index(element) + 5 - len(col) + 1
            j = cols.index(col)
            element_info['PTC'] = 'PTC' + str(j + 1)
            element_info['idx'] = (i,j)
    periodic_table_info[element] = element_info
    
for element in lanthanides:
    periodic_table_info[element] = {'mass' : atomic_masses[element], 'PTC' : 'Lant', 'idx' : (-1, -1)}

# %%
periodic_table_info
# Out:
# {'Ag': {'mass': 107.8682,
#   'valence_band': '4d^10-5s^1',
#   'PTC': 'PTC11',
#   'idx': (4, 10)},
#  'Al': {'mass': 26.9815,
#   'valence_band': '3s^2-3p^1',
#   'PTC': 'PTC13',
#   'idx': (2, 12)},
#  'Ar': {'mass': 39.0983,
#   'valence_band': '3s^2-3p^6',
#   'PTC': 'PTC18',
#   'idx': (2, 17)},
#  'As': {'mass': 74.9216,
#   'valence_band': '3d^10-4s^2-4p^3',
#   'PTC': 'PTC15',
#   'idx': (3, 14)},
#  'Au': {'mass': 196.9665,
#   'valence_band': '4f^14-5d^10-6s^1',
#   'PTC': 'PTC11',
#   'idx': (5, 10)},
#  'B': {'mass': 10.811,
#   'valence_band': '2s^2-2p^1',
#   'PTC': 'PTC13',
#   'idx': (1, 12)},
#  'Ba': {'mass': 137.327, 'valence_band': '6s^2', 'PTC': 'PTC2', 'idx': (5, 1)},
#  'Be': {'mass': 9.0122, 'valence_band': '2s^2', 'PTC': 'PTC2', 'idx': (1, 1)},
#  'Bi': {'mass': 208.9804,
#   'valence_band': '4f^14-5d^10-6s^2-6p^3',
#   'PTC': 'PTC15',
#   'idx': (5, 14)},
#  'Br': {'mass': 79.904,
#   'valence_band': '3d^10-4s^2-4p^5',
#   'PTC': 'PTC17',
# ...

# %% [markdown]
# # Check encoding

# %%
colnames = ['PTC' + str(n) for n in range(1, 19)]
colnames.append('Lant')

for col in colnames:
    print("----", col, '----')
    for elt, elt_info in periodic_table_info.items():
        if elt_info['PTC'] == col:
            print(elt)
# Out:
# ---- PTC1 ----
# Cs
# H
# K
# Li
# Na
# Rb
# ---- PTC2 ----
# Ba
# Be
# Ca
# Mg
# Sr
# ---- PTC3 ----
# Sc
# Y
# ---- PTC4 ----
# Hf
# Ti
# Zr
# ---- PTC5 ----
# Nb
# Ta
# V
# ---- PTC6 ----
# Cr
# Mo
# W
# ---- PTC7 ----
# Mn
# Re
# Tc
# ---- PTC8 ----
# Fe
# Os
# Ru
# ---- PTC9 ----
# Co
# Ir
# Rh
# ---- PTC10 ----
# Ni
# Pd
# Pt
# ---- PTC11 ----
# Ag
# Au
# Cu
# ---- PTC12 ----
# Cd
# Hg
# Zn
# ---- PTC13 ----
# Al
# B
# Ga
# In
# Tl
# ---- PTC14 ----
# C
# Ge
# Pb
# Si
# Sn
# ---- PTC15 ----
# As
# Bi
# N
# P
# Sb
# ---- PTC16 ----
# O
# Po
# S
# Se
# Te
# ---- PTC17 ----
# Br
# Cl
# F
# I
# ---- PTC18 ----
# Ar
# He
# Kr
# Ne
# Rn
# Xe
# ---- Lant ----
# Ce
# Dy
# Er
# Eu
# Gd
# Ho
# La
# Lu
# Nd
# Pm
# Pr
# Sm
# Tb
# Tm
# Yb

# %% [markdown]
# # Save to json

# %%
filename = 'periodic_table_info'

# %%
JSON_PATH = os.path.join(os.path.dirname(os.path.dirname(os.getcwd())), "code/data_preprocessing/" + filename + ".json")
with open(JSON_PATH, 'w') as write_file:
    json.dump(periodic_table_info, write_file)
